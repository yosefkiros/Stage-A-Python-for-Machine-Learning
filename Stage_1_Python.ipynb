# %%
import pandas as pd
Data = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="Latin-1")

print(Data)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
Grouped_data = Data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
Grouped_data
# Out:
# <ipython-input-7-e09a88d284f5>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Grouped_data = Data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...

# %%
Grouped_data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].max().reset_index()
# Out:
# <ipython-input-29-0501cc74d689>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Grouped_data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].max().reset_index()
#                                    Element       Y2014       Y2015  \
# 0                 Domestic supply quantity  1996716.35  2021493.55
# 1                          Export Quantity   150020.64   157614.47
# 2       Fat supply quantity (g/capita/day)    10225.56    10235.74
# 3                                     Feed   216927.89   225050.22
# 4                                     Food  1212332.49  1232361.10
# 5            Food supply (kcal/capita/day)   454257.00   453383.00
# 6      Food supply quantity (kg/capita/yr)    49650.63    49345.13
# 7                          Import Quantity   274144.48   267018.46
# 8                                   Losses   153223.00   155439.00
# ...
